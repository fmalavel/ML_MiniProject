# %% [markdown]
# # Notebook overview
#
# This notebook loads processed daily mean AQUM gridded fields and AURN-site-extracted values, then rasterizes (maps) AURN site ozone observations back onto the AQUM model grid using nearest-neighbour assignment. For each daily time step, it saves the rasterized ozone field together with corresponding meteorological variables (temperature, pressure, relative humidity, wind components) and gridded ozone as separate NetCDF files—enabling structured training data generation for downstream machine-learning pipelines.

# %% [markdown]
# # Imports

# %%
#import matplotlib.pyplot as plt
import warnings
# turn off futurewarning from iris
warnings.filterwarnings("ignore", category=FutureWarning)
# turn off netcdf unknown variable warning from iris
warnings.filterwarnings("ignore", category=UserWarning, message=".*NetCDF variable.*")
# turn off IrisCfNonSpanningVarWarning
warnings.filterwarnings("ignore", category=UserWarning, message=".*IrisCfNonSpanningVarWarning.*")

import numpy as np

from matplotlib import pyplot as plt

import iris
from iris.analysis.cartography import unrotate_pole
iris.FUTURE.save_split_attrs = True
# iris.FUTURE.datum_support = False
# Out:
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)

# %% [markdown]
# # Main

# %% [markdown]
# ## Read daily means from netcdf

# %%
# filter by site_type to get only rural sites 
site_constraint = iris.Constraint(site_type=['RURAL_BACKGROUND'])
site_constraint = iris.Constraint(site_type=['RURAL_BACKGROUND', 'URBAN_BACKGROUND','SUBURBAN_BACKGROUND'])

# load the hourly means from post processed files
model_datadir = 'processed_data/'
gridded_cube_list_daily = iris.load(model_datadir + '/AQUM-C_gridded_cube_list_daily_means.nc')
site_cube_list_daily = iris.load(model_datadir + '/AQUM-C_sites_cube_list_daily_means.nc', site_constraint)

print(f"\nGridded cube list after loading daily means:")
print(gridded_cube_list_daily)
print(f"\nSite cube list after loading daily means:")
print(site_cube_list_daily)

print("\nChecking short_name attributes in gridded cube list:")
for cube in gridded_cube_list_daily:
    if 'short_name' in cube.attributes:
        print(f" ... short_name: {cube.attributes['short_name']}")

# extracting specific fields from the gridded cube list and site cube list using short_name constraints 
Ozone_constraint = iris.AttributeConstraint(short_name='O3')
ozone_gridded = gridded_cube_list_daily.extract_cube(Ozone_constraint)

t_1p5_constraint = iris.AttributeConstraint(short_name='T_1p5')
t_1p5_gridded = gridded_cube_list_daily.extract_cube(t_1p5_constraint)

p_msl_constraint = iris.AttributeConstraint(short_name='p_msl')
p_msl_gridded = gridded_cube_list_daily.extract_cube(p_msl_constraint)

rh_1p5_constraint = iris.AttributeConstraint(short_name='rh_1p5')
rh_1p5_gridded = gridded_cube_list_daily.extract_cube(rh_1p5_constraint)

u_10m_constraint = iris.AttributeConstraint(short_name='u_10m')
u_10m_gridded = gridded_cube_list_daily.extract_cube(u_10m_constraint)

v_10m_constraint = iris.AttributeConstraint(short_name='v_10m')
v_10m_gridded = gridded_cube_list_daily.extract_cube(v_10m_constraint)

jNO2_constraint = iris.AttributeConstraint(short_name='jNO2')
jNO2_gridded = gridded_cube_list_daily.extract_cube(jNO2_constraint)

precip_constraint = iris.AttributeConstraint(short_name='total_precip')
precip_gridded = gridded_cube_list_daily.extract_cube(precip_constraint)

# ozone at sites
ozone_sites = site_cube_list_daily.extract_cube(Ozone_constraint)
# Out:
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_ozone_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_ozone_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_ozone_in_air: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_ammonia_in_air: Dimensions ('time_1',) do not span ('time_0', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_ammonia_in_air: Dimensions ('time_1',) do not span ('time_0', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable photolysis_rate_of_nitrogen_dioxide: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable photolysis_rate_of_nitrogen_dioxide: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable photolysis_rate_of_nitrogen_dioxide: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_nitrogen_monoxide_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_nitrogen_monoxide_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_nitrogen_monoxide_in_air: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_nitrogen_dioxide_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_nitrogen_dioxide_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_nitrogen_dioxide_in_air: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable photolysis_rate_of_ozone_to_1d_oxygen_atom: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable photolysis_rate_of_ozone_to_1d_oxygen_atom: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable photolysis_rate_of_ozone_to_1d_oxygen_atom: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_sulfur_dioxide_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_sulfur_dioxide_in_air: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_sulfur_dioxide_in_air: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable precipitation_amount: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable precipitation_amount: Dimensions ('time_1',) do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable precipitation_amount: Dimensions ('time_1', 'string95') do not span ('time', 'grid_latitude', 'grid_longitude')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_ozone_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_ozone_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_ozone_in_air: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_ammonia_in_air: Dimensions ('time',) do not span ('site_id', 'time_0')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_ammonia_in_air: Dimensions ('time',) do not span ('site_id', 'time_0')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable photolysis_rate_of_nitrogen_dioxide: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable photolysis_rate_of_nitrogen_dioxide: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable photolysis_rate_of_nitrogen_dioxide: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_nitrogen_monoxide_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_nitrogen_monoxide_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_nitrogen_monoxide_in_air: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_nitrogen_dioxide_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_nitrogen_dioxide_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_nitrogen_dioxide_in_air: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable photolysis_rate_of_ozone_to_1d_oxygen_atom: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable photolysis_rate_of_ozone_to_1d_oxygen_atom: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable photolysis_rate_of_ozone_to_1d_oxygen_atom: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable mass_concentration_of_sulfur_dioxide_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable mass_concentration_of_sulfur_dioxide_in_air: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable mass_concentration_of_sulfur_dioxide_in_air: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable day_of_year referenced by variable precipitation_amount: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable year referenced by variable precipitation_amount: Dimensions ('time',) do not span ('site_id', 'time_1')
#   warnings.warn(
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/cf.py:1618: IrisCfNonSpanningVarWarning: Ignoring variable month referenced by variable precipitation_amount: Dimensions ('time', 'string95') do not span ('site_id', 'time_1')
#   warnings.warn(
# Gridded cube list after loading daily means:
# 0: day_of_year / (1)                   (time: 93)
# 1: month / (unknown)                   (time: 93; -- : 95)
# 2: year / (1)                          (time: 93)
# 3: air_pressure_at_sea_level / (Pa)    (time: 93; grid_latitude: 112; grid_longitude: 88)
# 4: air_temperature / (K)               (time: 93; grid_latitude: 112; grid_longitude: 88)
# 5: mass_concentration_of_ammonia_in_air / (ug/m3) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 6: mass_concentration_of_nitrogen_dioxide_in_air / (ug/m3) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 7: mass_concentration_of_nitrogen_monoxide_in_air / (ug/m3) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 8: mass_concentration_of_ozone_in_air / (ug/m3) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 9: mass_concentration_of_sulfur_dioxide_in_air / (ug/m3) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 10: photolysis_rate_of_nitrogen_dioxide / (s-1) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 11: photolysis_rate_of_ozone_to_1D_oxygen_atom / (s-1) (time: 93; grid_latitude: 112; grid_longitude: 88)
# 12: precipitation_amount / (kg m-2)     (time: 93; grid_latitude: 112; grid_longitude: 88)
# 13: relative_humidity / (%)             (time: 93; grid_latitude: 112; grid_longitude: 88)
# 14: x_wind / (m s-1)                    (time: 93; grid_latitude: 112; grid_longitude: 87)
# 15: y_wind / (m s-1)                    (time: 93; grid_latitude: 112; grid_longitude: 87)
#
# Site cube list after loading daily means:
# 0: air_pressure_at_sea_level / (Pa)    (site_id: 108; time: 93)
# 1: air_temperature / (K)               (site_id: 108; time: 93)
# 2: mass_concentration_of_ammonia_in_air / (ug/m3) (site_id: 108; time: 93)
# 3: mass_concentration_of_nitrogen_dioxide_in_air / (ug/m3) (site_id: 108; time: 93)
# 4: mass_concentration_of_nitrogen_monoxide_in_air / (ug/m3) (site_id: 108; time: 93)
# 5: mass_concentration_of_ozone_in_air / (ug/m3) (site_id: 108; time: 93)
# 6: mass_concentration_of_sulfur_dioxide_in_air / (ug/m3) (site_id: 108; time: 93)
# 7: photolysis_rate_of_nitrogen_dioxide / (s-1) (site_id: 108; time: 93)
# 8: photolysis_rate_of_ozone_to_1D_oxygen_atom / (s-1) (site_id: 108; time: 93)
# 9: precipitation_amount / (kg m-2)     (site_id: 108; time: 93)
# 10: relative_humidity / (%)             (site_id: 108; time: 93)
# 11: x_wind / (m s-1)                    (site_id: 108; time: 93)
# 12: y_wind / (m s-1)                    (site_id: 108; time: 93)
#
# Checking short_name attributes in gridded cube list:
#  ... short_name: p_msl
#  ... short_name: T_1p5
#  ... short_name: NH3
#  ... short_name: NO2
#  ... short_name: NO
#  ... short_name: O3
#  ... short_name: SO2
#  ... short_name: jNO2
#  ... short_name: jO1D
#  ... short_name: total_precip
#  ... short_name: rh_1p5
#  ... short_name: u_10m
#  ... short_name: v_10m

# %% [markdown]
# ## Loop over time

# %%
# extract dimension of arrays
ntime = ozone_gridded.coord('time').points.size
nlat = ozone_gridded.coord('grid_latitude').points.size
nlon = ozone_gridded.coord('grid_longitude').points.size
print(f"Ozone gridded cube dimensions: time={ntime}, lat={nlat},  lon={nlon}")

nsites = ozone_sites.coord('site_id').points.size
print(f"Ozone sites cube dimensions: time={ntime}, sites={nsites}")

# initialise a cube list to hold the rasterized ozone values at the AURN sites
rasterized_ozone_at_aurn_site = np.empty((ntime, nlat, nlon))

# initialize lists to store site lat/lon, rotated lat/lon and ozone values
sites_lat = np.empty((ntime, nsites))
sites_lon = np.empty((ntime, nsites))
sites_rotated_lat = np.empty((ntime, nsites))
sites_rotated_lon = np.empty((ntime, nsites))
sites_ozone = np.empty((ntime, nsites))
date_str = []

# set the number of time steps to process (for testing, set to 1 or 2, for full processing set to ntime)
nstop = ntime
# nstop = 10

for nt, (ozone_gridded_time_slice, 
         t_1p5_gridded_time_slice,
         rh_1p5_gridded_time_slice,
         p_msl_gridded_time_slice,
         u_10m_gridded_time_slice,
         v_10m_gridded_time_slice,
         ozone_at_site_time_slice,
         jNO2_gridded_time_slice,
         precip_gridded_time_slice) in enumerate(zip(
            ozone_gridded.slices_over('time'),
            t_1p5_gridded.slices_over('time'),
            rh_1p5_gridded.slices_over('time'),
            p_msl_gridded.slices_over('time'),
            u_10m_gridded.slices_over('time'),
            v_10m_gridded.slices_over('time'),
            ozone_sites.slices_over('time'),
            jNO2_gridded.slices_over('time'),
            precip_gridded.slices_over('time'),
            )):

    # print(ozone_gridded_time_slice)
    # print(p_msl_gridded_time_slice)
    # print("\n\n")

    # end loop after nstop iteration
    if nt >= nstop:
        break

    # extract the time coordinate and convert to datetime for printing
    time_coord = ozone_gridded_time_slice.coord('time')
    dt = time_coord.units.num2date(time_coord.points)       # returns an array-like of datetimes
    date_str.append(dt[0].strftime("%Y-%m-%d %H:%M:%S"))          # format as you like
    print(f'\n{nt} - Processing cubes for date: {date_str[nt]}')

    ozone_field = ozone_gridded_time_slice.copy()
    ozone_field.data = np.full_like(ozone_gridded_time_slice.data, np.nan)
    rasterized_ozone_at_aurn_site[nt, :, :] = ozone_field.data

    # Define the unrotated grid for AQUM
    if nt == 0:
        # Rotated pole properties
        pole_lon = ozone_gridded_time_slice.coord('grid_longitude').coord_system.grid_north_pole_longitude
        pole_lat = ozone_gridded_time_slice.coord('grid_latitude').coord_system.grid_north_pole_latitude
        lat_grid = ozone_gridded_time_slice.coord('grid_latitude').points
        lon_grid = ozone_gridded_time_slice.coord('grid_longitude').points - 360.0
        # print(f"\nTarget lat grid: {lat_grid}")
        # print(f"\nTarget lon grid: {lon_grid}")
        lon2d, lat2d = np.meshgrid(lon_grid, lat_grid)
        lon2d_unrotated, lat2d_unrotated = unrotate_pole(lon2d, lat2d, pole_lon, pole_lat)


    # unpack the ozone at sites values and coords
    for ns, site in enumerate(ozone_at_site_time_slice.slices_over('site_id')):

        # Read sites values, lat/lon and rotated lat/lon from the cube coordinates
        # site_id = site.coord('site_id').points[0]
        site_lat = site.coord('latitude').points[0]
        site_lon = site.coord('longitude').points[0]
        site_rotated_lat = site.coord('grid_latitude').points[0]
        site_rotated_lon = site.coord('grid_longitude').points[0]

        # print(f"Site ID: {site_id}")
        # print(f"Site lat: {site_lat}, Site lon: {site_lon}")
        # print(f"Site rotated lat: {site_rotated_lat}, Site rotated lon: {site_rotated_lon}")

        # Append the values to the arrays
        sites_ozone[nt, ns] = site.data
        sites_lat[nt, ns] = site_lat
        sites_lon[nt, ns] = site_lon
        sites_rotated_lat[nt, ns] = site_rotated_lat
        sites_rotated_lon[nt, ns] = site_rotated_lon

    # Find nearest indices to the model lat/lon grid points for each site and create a unique id
    unique_ids = []
    for ns in range(nsites):
        # find the nearest grid point to the site rotated lat/lon
        nearest_lat_idx = np.argmin(np.abs(lat_grid - sites_rotated_lat[nt, ns]))
        nearest_lon_idx = np.argmin(np.abs(lon_grid - sites_rotated_lon[nt, ns]))
        # print(f"Site {ns}: nearest grid point indices - lat: {nearest_lat_idx}, lon: {nearest_lon_idx}")

        # define a unique id for the grid point based on its lat and lon indices
        unique_id = nearest_lat_idx * nlon + nearest_lon_idx
        unique_ids.append(unique_id)
        # print(f"Site {ns}: unique id for nearest grid point: {unique_id}")

    print(f"sites_ozone [{nt,0}]: {sites_ozone[nt,0]}")
    print(f"sites_ozone [{nt,2}]: {sites_ozone[nt,2]}")

    # for sites with same unique_id, calculate an average value for ozone and assign to the grid point
    unique_id_counts = {uid: unique_ids.count(uid) for uid in set(unique_ids)}
    print(f"set(unique_ids): {set(unique_ids)}")
    
    for ns in range(nsites):
        nearest_lat_idx = np.argmin(np.abs(lat_grid - sites_rotated_lat[nt, ns]))
        nearest_lon_idx = np.argmin(np.abs(lon_grid - sites_rotated_lon[nt, ns]))
        unique_id = nearest_lat_idx * nlon + nearest_lon_idx
        if unique_id_counts[unique_id] > 1:
            # find all sites with the same unique_id
            duplicate_sites = [i for i, uid in enumerate(unique_ids) if uid == unique_id]
            # calculate the average ozone value for these sites
            avg_ozone = np.mean([sites_ozone[nt, i] for i in duplicate_sites])
            rasterized_ozone_at_aurn_site[nt, nearest_lat_idx, nearest_lon_idx] = avg_ozone
            print(f"Site {ns}: Assigned average ozone value {avg_ozone} to grid point with unique id {unique_id} for duplicate sites {duplicate_sites}")
        else:
            # assign the site ozone value to the grid point if there are no duplicates
            rasterized_ozone_at_aurn_site[nt, nearest_lat_idx, nearest_lon_idx] = sites_ozone[nt, ns]
        
    # print the number of non nan values in the rasterized ozone field for this time step
    num_non_nan = np.count_nonzero(~np.isnan(rasterized_ozone_at_aurn_site[nt, :, :]))
    print(f"Number of non-NaN values in rasterized ozone field at time step {nt}: {num_non_nan} out of {nlat*nlon} grid points")   

    # ---------------------------------------------------------------------------------------
    #  SAVING THE RASTERIZED OZONE FIELD AND AQUM FIELDS FOR THIS TIME STEP TO A NETCDF FILE
    # ---------------------------------------------------------------------------------------
    # for each time step save the rasterized ozone field as a 2D array (lat x lon) in a netcdf file with the date in the filename
    output_path = f"processed_data/Daily_snapshots/rasterized_ozone_at_aurn_sites_{date_str[nt]}.nc"

    # create a new cube for the rasterized ozone field at this time step
    rasterized_ozone_cube = iris.cube.Cube(
        rasterized_ozone_at_aurn_site[nt, :, :],
        long_name='rasterized_aqum_O3_at_AURN_sites',
        var_name='rasterized_aqum_O3_at_AURN_sites',
        units='ug/m3',
        dim_coords_and_dims=[
            (ozone_gridded_time_slice.coord('grid_latitude').copy(), 0),
            (ozone_gridded_time_slice.coord('grid_longitude').copy(), 1),
        ],
    )
    rasterized_ozone_cube.add_aux_coord(ozone_gridded_time_slice.coord('time').copy())
    # iris.save(rasterized_ozone_cube, output_path)

    # Save all required cubes in one write, then skip the append calls below.
    cubes_to_save = iris.cube.CubeList([
        rasterized_ozone_cube,
        t_1p5_gridded_time_slice,
        rh_1p5_gridded_time_slice,
        p_msl_gridded_time_slice,
        u_10m_gridded_time_slice,
        v_10m_gridded_time_slice,
        jNO2_gridded_time_slice,
        precip_gridded_time_slice
    ])
    iris.save(cubes_to_save, output_path)

    output_path = f"processed_data/Daily_snapshots/y_train_ozone_fields_{date_str[nt]}.nc"
    iris.save(ozone_gridded_time_slice, output_path)
# Out:
# Ozone gridded cube dimensions: time=93, lat=112,  lon=88
# Ozone sites cube dimensions: time=93, sites=108
#
# 0 - Processing cubes for date: 2025-05-01 11:00:00
# sites_ozone [(0, 0)]: 66.92263793945312
# sites_ozone [(0, 2)]: 63.42683029174805
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 65.17473411560059 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 65.17473411560059 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 115.1781005859375 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 115.1781005859375 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 115.65542093912761 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 115.65542093912761 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 115.65542093912761 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 78.68533706665039 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 78.68533706665039 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 75.64404296875 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 75.64404296875 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 78.67240142822266 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 74.08153533935547 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 74.08153533935547 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 78.67240142822266 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 0: 100 out of 9856 grid points
# /data/users/florent.malavelle/.conda/envs/MLFoundationsEnv/lib/python3.11/site-packages/iris/fileformats/netcdf/saver.py:2832: IrisSaveWarning: Saving the cube global attributes ['Conventions'] as local (i.e. data-variable) attributes, where possible, since they are not the same on all input cubes.
#   warnings.warn(
# 1 - Processing cubes for date: 2025-05-02 11:00:00
# sites_ozone [(1, 0)]: 61.28615951538086
# sites_ozone [(1, 2)]: 62.841121673583984
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 62.06364059448242 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 62.06364059448242 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 79.79307556152344 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 79.79307556152344 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 83.32004292805989 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 83.32004292805989 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 83.32004292805989 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 85.19989013671875 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 85.19989013671875 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 91.0873031616211 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 91.0873031616211 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 90.28089904785156 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 90.91410446166992 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 90.91410446166992 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 90.28089904785156 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 1: 100 out of 9856 grid points
#
# 2 - Processing cubes for date: 2025-05-03 11:00:00
# sites_ozone [(2, 0)]: 85.37899780273438
# sites_ozone [(2, 2)]: 84.05603790283203
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 84.7175178527832 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 84.7175178527832 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 76.7259292602539 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 76.7259292602539 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 74.50887298583984 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 74.50887298583984 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 74.50887298583984 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 82.54183959960938 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 82.54183959960938 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 83.19701385498047 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 83.19701385498047 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 83.40230560302734 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 81.94463729858398 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 81.94463729858398 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 83.40230560302734 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 2: 100 out of 9856 grid points
#
# 3 - Processing cubes for date: 2025-05-04 11:00:00
# sites_ozone [(3, 0)]: 82.64481353759766
# sites_ozone [(3, 2)]: 83.02799224853516
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 82.8364028930664 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 82.8364028930664 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 83.37228012084961 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 83.37228012084961 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 86.01381429036458 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 86.01381429036458 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 86.01381429036458 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 83.6856918334961 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 83.6856918334961 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 85.12036895751953 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 85.12036895751953 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 85.0863151550293 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 84.61056900024414 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 84.61056900024414 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 85.0863151550293 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 3: 100 out of 9856 grid points
#
# 4 - Processing cubes for date: 2025-05-05 11:00:00
# sites_ozone [(4, 0)]: 85.87198638916016
# sites_ozone [(4, 2)]: 86.33013916015625
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 86.1010627746582 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 86.1010627746582 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 88.31425094604492 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 88.31425094604492 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 84.81361134847005 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 84.81361134847005 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 84.81361134847005 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 86.81946182250977 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 86.81946182250977 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 88.85133361816406 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 88.85133361816406 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 88.0223159790039 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 88.2975082397461 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 88.2975082397461 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 88.0223159790039 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 4: 100 out of 9856 grid points
#
# 5 - Processing cubes for date: 2025-05-06 11:00:00
# sites_ozone [(5, 0)]: 81.3037109375
# sites_ozone [(5, 2)]: 81.43289947509766
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 81.36830520629883 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 81.36830520629883 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 79.86944580078125 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 79.86944580078125 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 80.39264424641927 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 80.39264424641927 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 80.39264424641927 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 77.40744400024414 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 77.40744400024414 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 78.37074279785156 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 78.37074279785156 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 77.75471496582031 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 78.16683197021484 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 78.16683197021484 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 77.75471496582031 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 5: 100 out of 9856 grid points
#
# 6 - Processing cubes for date: 2025-05-07 11:00:00
# sites_ozone [(6, 0)]: 76.78165435791016
# sites_ozone [(6, 2)]: 77.4371337890625
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 77.10939407348633 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 77.10939407348633 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 79.62042236328125 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 79.62042236328125 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 72.45898183186848 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 72.45898183186848 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 72.45898183186848 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 76.3366584777832 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 76.3366584777832 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 78.12947845458984 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 78.12947845458984 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 78.8062515258789 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 77.42683410644531 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 77.42683410644531 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 78.8062515258789 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 6: 100 out of 9856 grid points
#
# 7 - Processing cubes for date: 2025-05-08 11:00:00
# sites_ozone [(7, 0)]: 81.80127716064453
# sites_ozone [(7, 2)]: 82.46973419189453
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 82.13550567626953 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 82.13550567626953 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 84.5656623840332 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 84.5656623840332 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 86.27030436197917 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 86.27030436197917 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 86.27030436197917 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 86.33673858642578 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 86.33673858642578 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 87.5481948852539 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 87.5481948852539 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 87.13661193847656 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 86.88662719726562 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 86.88662719726562 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 87.13661193847656 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 7: 100 out of 9856 grid points
#
# 8 - Processing cubes for date: 2025-05-09 11:00:00
# sites_ozone [(8, 0)]: 84.42664337158203
# sites_ozone [(8, 2)]: 84.02450561523438
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 84.2255744934082 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 84.2255744934082 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 90.53149795532227 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 90.53149795532227 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 83.82060241699219 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 83.82060241699219 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 83.82060241699219 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 86.85063934326172 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 86.85063934326172 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 88.13168334960938 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 88.13168334960938 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 86.3653678894043 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 87.92671966552734 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 87.92671966552734 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 86.3653678894043 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 8: 100 out of 9856 grid points
#
# 9 - Processing cubes for date: 2025-05-10 11:00:00
# sites_ozone [(9, 0)]: 73.7591323852539
# sites_ozone [(9, 2)]: 71.96244049072266
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 72.86078643798828 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 72.86078643798828 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 90.79923629760742 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 90.79923629760742 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 86.36397043863933 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 86.36397043863933 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 86.36397043863933 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 86.2626953125 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 86.2626953125 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 85.97118377685547 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 85.97118377685547 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 83.63594055175781 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 85.67041015625 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 85.67041015625 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 83.63594055175781 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 9: 100 out of 9856 grid points
#
# 10 - Processing cubes for date: 2025-05-11 11:00:00
# sites_ozone [(10, 0)]: 76.1482162475586
# sites_ozone [(10, 2)]: 74.93319702148438
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 75.54070663452148 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 75.54070663452148 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 98.53730010986328 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 98.53730010986328 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 90.9444071451823 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 90.9444071451823 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 90.9444071451823 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 83.46041870117188 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 83.46041870117188 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 82.88634872436523 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 82.88634872436523 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 79.26826095581055 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 83.04188537597656 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 83.04188537597656 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 79.26826095581055 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 10: 100 out of 9856 grid points
#
# 11 - Processing cubes for date: 2025-05-12 11:00:00
# sites_ozone [(11, 0)]: 74.5422134399414
# sites_ozone [(11, 2)]: 73.6573715209961
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 74.09979248046875 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 74.09979248046875 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 85.15307235717773 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 85.15307235717773 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 82.92573801676433 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 82.92573801676433 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 82.92573801676433 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 74.73593139648438 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 74.73593139648438 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 68.052978515625 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 68.052978515625 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 71.57170867919922 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 63.952613830566406 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 63.952613830566406 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 71.57170867919922 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 11: 100 out of 9856 grid points
#
# 12 - Processing cubes for date: 2025-05-13 11:00:00
# sites_ozone [(12, 0)]: 62.4326057434082
# sites_ozone [(12, 2)]: 60.07466506958008
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 61.25363540649414 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 61.25363540649414 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 91.46770858764648 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 91.46770858764648 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 89.66727193196614 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 89.66727193196614 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 89.66727193196614 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 76.0386848449707 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 76.0386848449707 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 77.63689422607422 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 77.63689422607422 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 72.62599563598633 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 79.52426147460938 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 79.52426147460938 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 72.62599563598633 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 12: 100 out of 9856 grid points
#
# 13 - Processing cubes for date: 2025-05-14 11:00:00
# sites_ozone [(13, 0)]: 91.14373779296875
# ...
# Site 75: Assigned average ozone value 63.9466438293457 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 63.9466438293457 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 62.44833946228027 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 62.44833946228027 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 68.83691787719727 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 68.83691787719727 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 70.55809020996094 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 69.21907424926758 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 69.21907424926758 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 70.55809020996094 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 88: 100 out of 9856 grid points
#
# 89 - Processing cubes for date: 2025-07-29 11:00:00
# sites_ozone [(89, 0)]: 58.0051383972168
# sites_ozone [(89, 2)]: 58.950313568115234
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 58.477725982666016 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 58.477725982666016 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 51.844797134399414 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 51.844797134399414 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 63.66156260172526 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 63.66156260172526 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 63.66156260172526 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 59.484012603759766 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 59.484012603759766 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 65.10917663574219 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 65.10917663574219 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 66.2057991027832 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 64.90337371826172 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 64.90337371826172 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 66.2057991027832 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 89: 100 out of 9856 grid points
#
# 90 - Processing cubes for date: 2025-07-30 11:00:00
# sites_ozone [(90, 0)]: 53.23917770385742
# sites_ozone [(90, 2)]: 54.680755615234375
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 53.9599666595459 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 53.9599666595459 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 50.365976333618164 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 50.365976333618164 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 58.658257802327476 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 58.658257802327476 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 58.658257802327476 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 49.50221252441406 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 49.50221252441406 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 53.81467247009277 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 53.81467247009277 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 54.875654220581055 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 55.228254318237305 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 55.228254318237305 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 54.875654220581055 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 90: 100 out of 9856 grid points
#
# 91 - Processing cubes for date: 2025-07-31 11:00:00
# sites_ozone [(91, 0)]: 51.50740432739258
# sites_ozone [(91, 2)]: 51.63534927368164
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 51.57137680053711 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 51.57137680053711 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 60.013275146484375 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 60.013275146484375 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 60.72117487589518 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 60.72117487589518 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 60.72117487589518 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 59.843027114868164 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 59.843027114868164 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 63.18951416015625 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 63.18951416015625 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 63.93630027770996 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 63.3518180847168 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 63.3518180847168 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 63.93630027770996 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 91: 100 out of 9856 grid points
#
# 92 - Processing cubes for date: 2025-07-31 23:30:00
# sites_ozone [(92, 0)]: 61.24018859863281
# sites_ozone [(92, 2)]: 61.08633804321289
# set(unique_ids): {np.int64(6656), np.int64(4612), np.int64(1546), np.int64(4107), np.int64(4110), np.int64(1558), np.int64(2074), np.int64(1562), np.int64(4637), np.int64(1566), np.int64(2078), np.int64(5154), np.int64(2087), np.int64(2090), np.int64(2092), np.int64(2093), np.int64(2094), np.int64(2096), np.int64(5683), np.int64(3139), np.int64(3660), np.int64(3662), np.int64(3663), np.int64(3664), np.int64(3666), np.int64(3668), np.int64(3673), np.int64(1644), np.int64(2163), np.int64(1652), np.int64(2170), np.int64(3710), np.int64(2179), np.int64(2180), np.int64(2693), np.int64(2184), np.int64(2185), np.int64(2696), np.int64(2703), np.int64(3228), np.int64(1189), np.int64(3749), np.int64(3755), np.int64(4786), np.int64(1725), np.int64(2251), np.int64(4812), np.int64(2267), np.int64(2787), np.int64(6377), np.int64(2798), np.int64(3312), np.int64(2804), np.int64(3317), np.int64(3318), np.int64(3330), np.int64(3843), np.int64(3850), np.int64(4375), np.int64(2330), np.int64(1820), np.int64(4899), np.int64(5419), np.int64(2349), np.int64(2873), np.int64(2362), np.int64(2874), np.int64(2875), np.int64(3398), np.int64(9036), np.int64(3405), np.int64(3923), np.int64(3925), np.int64(3926), np.int64(1367), np.int64(3931), np.int64(4957), np.int64(3938), np.int64(2432), np.int64(5506), np.int64(2955), np.int64(2961), np.int64(4514), np.int64(3492), np.int64(7083), np.int64(1466), np.int64(5070), np.int64(2000), np.int64(5589), np.int64(5594), np.int64(2528), np.int64(3045), np.int64(3046), np.int64(6124), np.int64(3054), np.int64(3058), np.int64(3571), np.int64(3059), np.int64(3067), np.int64(3580)}
# Site 0: Assigned average ozone value 61.16326332092285 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 2: Assigned average ozone value 61.16326332092285 to grid point with unique id 1566 for duplicate sites [0, 2]
# Site 54: Assigned average ozone value 53.096771240234375 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 55: Assigned average ozone value 53.096771240234375 to grid point with unique id 2961 for duplicate sites [54, 55]
# Site 71: Assigned average ozone value 48.4719492594401 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 75: Assigned average ozone value 48.4719492594401 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 77: Assigned average ozone value 48.4719492594401 to grid point with unique id 3668 for duplicate sites [71, 75, 77]
# Site 92: Assigned average ozone value 69.41542053222656 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 96: Assigned average ozone value 69.41542053222656 to grid point with unique id 2090 for duplicate sites [92, 96]
# Site 100: Assigned average ozone value 70.88743591308594 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 103: Assigned average ozone value 70.88743591308594 to grid point with unique id 2179 for duplicate sites [100, 103]
# Site 104: Assigned average ozone value 73.35952377319336 to grid point with unique id 2092 for duplicate sites [104, 107]
# Site 105: Assigned average ozone value 68.37002182006836 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 106: Assigned average ozone value 68.37002182006836 to grid point with unique id 2180 for duplicate sites [105, 106]
# Site 107: Assigned average ozone value 73.35952377319336 to grid point with unique id 2092 for duplicate sites [104, 107]
# Number of non-NaN values in rasterized ozone field at time step 92: 100 out of 9856 grid points

# %% [markdown]
# # Quick plot

# %%
cmap = 'Spectral_r' 

#plot the first five time steps of the rasterized ozone values
for nt in range(ntime):
    # plot first 5 time steps
    if nt >= 5:
        break

    print(f"Plotting time step {nt} - {date_str[nt]}")
    
    plt.figure(figsize=(8, 6))
    plt.scatter(lon2d_unrotated, lat2d_unrotated, c=rasterized_ozone_at_aurn_site[nt, :, :], edgecolor='black', cmap=cmap, vmin=50, vmax=125)
    plt.colorbar(label='Ozone Concentration (ug/m3)')
    plt.title(f'Rasterized AQUM Ozone at AURN Sites - Time Step {nt} - {date_str[nt]}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid()
    
    #  # UK map window (unrotated lon/lat)
    # uk_lon_min, uk_lon_max = -11.0, 3.0
    # uk_lat_min, uk_lat_max = 48.0, 61.5

    # # Apply UK zoom to the plot
    # plt.xlim(uk_lon_min, uk_lon_max)
    # plt.ylim(uk_lat_min, uk_lat_max)

    # add title with date
    plt.show()
# Out:
# Plotting time step 0 - 2025-05-01 11:00:00
# Plotting time step 1 - 2025-05-02 11:00:00
# Plotting time step 2 - 2025-05-03 11:00:00
# Plotting time step 3 - 2025-05-04 11:00:00
# Plotting time step 4 - 2025-05-05 11:00:00
